# %% [markdown]
# # Exercise -03
#
# IT No: IT22577160

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Load the MNIST dataset

# %%
(train_data,train_target),(test_data,test_target) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Visualize the dataset

# %%
fig, axs = plt.subplots(2, 5, figsize=(16,8))
random_numbers = np.random.randint(0, 60000, 10)
print('Target labels: ',train_target[random_numbers])
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(train_data[random_numbers[idx]],cmap='gray')
plt.show()
# Out:
# Target labels:  [3 1 6 4 3 9 1 2 7 1]

# %% [markdown]
# Pre-processing stage
#
# *   Before training, the data is pre-processed to make learning easier for the
# model.
#
# *   Pixel values are scaled from 0–255 to 0–1. This helps the model converge faster and improves numerical stability.

# %%
new_train_data = train_data/255.0
new_test_data=test_data/255.0

new_train_target = to_categorical(train_target)
new_test_target = to_categorical(test_target)

# %% [markdown]
# Create the Model architecture

# %% [markdown]
# ### **Part (a): Hyperparameter Tuning**
#
# Improved test accuracy by adjusting hyperparameters:
#
# *   Batch size = 128 (larger batches → faster, stable convergence).
#
# *   EarlyStopping with patience=7 and restore_best_weights=True to prevent  overfitting.
# *   Validation split = 0.2 for monitoring generalization.
#
# *   Learning rate = 0.0003 (Adam optimizer) for smoother training.
#
#
# ### **Part (b): Regularization**
#
# *   To reduce overfitting and enhance generalization, I added:
# *   L1 regularization: Promotes sparsity by shrinking less important weights.
# *   L2 regularization: Controls large weights, improving stability.
# *   Combined L1 + L2: Applied in the first two hidden layers; L2 used in the third layer.
#
#
# **The usage**
#
# *   Hidden Layer 1 & 2: l1=1e-5, l2=1e-4 (L1 + L2 regularization).
# *   Hidden Layer 3: l2=1e-4 only.
# *   Dropout: 0.3 (layer 1) and 0.2 (layer 2).

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

model = Sequential()
model.add(Flatten(input_shape=(28,28)))

# Hidden layer 1 with L1 + L2
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization()) #stabilizes and speeds up training.
model.add(Dropout(0.3)) #prevents overfitting, improves generalization.

# Hidden layer 2 with L1 + L2
model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Hidden layer 3 with L2 only
model.add(Dense(64, activation='relu',kernel_regularizer=regularizers.l2(1e-4)))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0003),
              metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# Larger batch → faster convergence.
# EarlyStopping → prevents overfitting.
# Validation split → allows monitoring generalization during training
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 244,298 (954.29 KB)
#  Trainable params: 243,530 (951.29 KB)
#  Non-trainable params: 768 (3.00 KB)

# %% [markdown]
# Train the model

# %%
train_info = model.fit(new_train_data, new_train_target,
                       epochs=50,
                       batch_size=64,
                       validation_split=0.1,
                       callbacks=[early_stop])
# Out:
# Epoch 1/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.7272 - loss: 1.0186 - val_accuracy: 0.9627 - val_loss: 0.2534
# Epoch 2/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9349 - loss: 0.3398 - val_accuracy: 0.9728 - val_loss: 0.2132
# Epoch 3/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9527 - loss: 0.2739 - val_accuracy: 0.9768 - val_loss: 0.1929
# Epoch 4/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9613 - loss: 0.2382 - val_accuracy: 0.9765 - val_loss: 0.1890
# Epoch 5/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9673 - loss: 0.2162 - val_accuracy: 0.9797 - val_loss: 0.1734
# Epoch 6/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9688 - loss: 0.2041 - val_accuracy: 0.9798 - val_loss: 0.1674
# Epoch 7/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9728 - loss: 0.1902 - val_accuracy: 0.9815 - val_loss: 0.1654
# Epoch 8/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9763 - loss: 0.1747 - val_accuracy: 0.9818 - val_loss: 0.1583
# Epoch 9/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9766 - loss: 0.1709 - val_accuracy: 0.9813 - val_loss: 0.1596
# Epoch 10/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9776 - loss: 0.1648 - val_accuracy: 0.9823 - val_loss: 0.1551
# Epoch 11/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9787 - loss: 0.1586 - val_accuracy: 0.9842 - val_loss: 0.1473
# Epoch 12/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9806 - loss: 0.1503 - val_accuracy: 0.9823 - val_loss: 0.1488
# Epoch 13/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9806 - loss: 0.1497 - val_accuracy: 0.9818 - val_loss: 0.1474
# Epoch 14/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9814 - loss: 0.1454 - val_accuracy: 0.9827 - val_loss: 0.1456
# Epoch 15/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9827 - loss: 0.1376 - val_accuracy: 0.9827 - val_loss: 0.1487
# Epoch 16/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9825 - loss: 0.1391 - val_accuracy: 0.9817 - val_loss: 0.1451
# Epoch 17/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9848 - loss: 0.1316 - val_accuracy: 0.9820 - val_loss: 0.1489
# Epoch 18/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9856 - loss: 0.1264 - val_accuracy: 0.9855 - val_loss: 0.1385
# Epoch 19/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9841 - loss: 0.1288 - val_accuracy: 0.9840 - val_loss: 0.1405
# Epoch 20/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9849 - loss: 0.1263 - val_accuracy: 0.9843 - val_loss: 0.1359
# Epoch 21/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9862 - loss: 0.1220 - val_accuracy: 0.9837 - val_loss: 0.1344
# Epoch 22/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9859 - loss: 0.1202 - val_accuracy: 0.9852 - val_loss: 0.1343
# Epoch 23/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9850 - loss: 0.1215 - val_accuracy: 0.9843 - val_loss: 0.1303
# Epoch 24/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9865 - loss: 0.1162 - val_accuracy: 0.9858 - val_loss: 0.1282
# Epoch 25/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9869 - loss: 0.1156 - val_accuracy: 0.9842 - val_loss: 0.1298
# Epoch 26/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9871 - loss: 0.1103 - val_accuracy: 0.9832 - val_loss: 0.1309
# Epoch 27/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9872 - loss: 0.1099 - val_accuracy: 0.9830 - val_loss: 0.1323
# Epoch 28/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9876 - loss: 0.1099 - val_accuracy: 0.9852 - val_loss: 0.1243
# Epoch 29/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9873 - loss: 0.1075 - val_accuracy: 0.9850 - val_loss: 0.1258
# Epoch 30/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9888 - loss: 0.1054 - val_accuracy: 0.9845 - val_loss: 0.1310
# Epoch 31/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9878 - loss: 0.1077 - val_accuracy: 0.9847 - val_loss: 0.1254
# Epoch 32/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9885 - loss: 0.1040 - val_accuracy: 0.9847 - val_loss: 0.1273
# Epoch 33/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9887 - loss: 0.1027 - val_accuracy: 0.9870 - val_loss: 0.1217
# Epoch 34/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9881 - loss: 0.1023 - val_accuracy: 0.9863 - val_loss: 0.1198
# Epoch 35/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9880 - loss: 0.1023 - val_accuracy: 0.9833 - val_loss: 0.1265
# Epoch 36/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9901 - loss: 0.0965 - val_accuracy: 0.9847 - val_loss: 0.1281
# Epoch 37/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9884 - loss: 0.1017 - val_accuracy: 0.9850 - val_loss: 0.1226
# Epoch 38/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9896 - loss: 0.0981 - val_accuracy: 0.9853 - val_loss: 0.1211
# Epoch 39/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9888 - loss: 0.0978 - val_accuracy: 0.9848 - val_loss: 0.1191
# Epoch 40/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9893 - loss: 0.0986 - val_accuracy: 0.9847 - val_loss: 0.1209
# Epoch 41/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9893 - loss: 0.0961 - val_accuracy: 0.9855 - val_loss: 0.1204
# Epoch 42/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9893 - loss: 0.0963 - val_accuracy: 0.9862 - val_loss: 0.1214
# Epoch 43/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9889 - loss: 0.0973 - val_accuracy: 0.9855 - val_loss: 0.1194
# Epoch 44/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9893 - loss: 0.0969 - val_accuracy: 0.9850 - val_loss: 0.1203
# Epoch 45/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9897 - loss: 0.0950 - val_accuracy: 0.9855 - val_loss: 0.1212
# Epoch 46/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9898 - loss: 0.0940 - val_accuracy: 0.9847 - val_loss: 0.1193

# %% [markdown]
# Plot the loss and accuracy graphs

# %%
plt.plot(train_info.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Model loss')
plt.show()

# %%
plt.plot(train_info.history['accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.title('Model accuracy')
plt.show()

# %% [markdown]
# Test the performance of Model

# %%
loss, acc = model.evaluate(new_test_data , new_test_target)
print(f'Loss of the Test dataset is: {loss}\nAccuracy of the test dataset is: {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9803 - loss: 0.1401
# Loss of the Test dataset is: 0.12524913251399994
# Accuracy of the test dataset is: 0.9835000038146973

# %% [markdown]
# Save the model weights

# %%
model.save_weights('MNIST_WEIGHTS_V1.weights.h5')

# %%
model.save('MNIST_MODEL_V1.keras')

# %% [markdown]
# ### **Part (c): Class-wise Performance with Confusion Matrix**
#
#   To evaluate the model’s performance across different digit classes, added visualized predictions using a confusion matrix.
#
#   Rows represent the actual digits, while columns represent the predicted digits.
#
#   The diagonal cells indicate correct classifications, and off-diagonal cells show misclassifications.
#
#   This helps identify which digits the model predicts well and where it struggles (ex:confusion between visually similar digits like 4 and 9).

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

y_pred = model.predict(new_test_data)
y_pred_classes = np.argmax(y_pred, axis=1)  # predicted digit
y_true = np.argmax(new_test_target, axis=1) # actual digit

cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))
disp.plot(cmap='Blues', xticks_rotation=45)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
